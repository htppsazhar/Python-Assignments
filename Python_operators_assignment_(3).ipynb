# %% [markdown]
# <a href="https://colab.research.google.com/github/htppsazhar/Python-Assignments/blob/main/Python_operators_assignment_(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Operators Practice Notebook
#
# Each question is followed by its solution in the next code cell.
# Difficulty level: Easy to Medium.

# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# Q1. Add two numbers a = 10 and b = 5.

# %%
a = 10
b = 5
sum = a + b
print(sum)
# Out:
# 15

# %% [markdown]
# Q2. Find the remainder when 17 is divided by 4.

# %%
num1 = int(input('Enter first number: '))
num2 = int(input('Enter second number:'))
remainder = num1 % num2
print(float(remainder))
# Out:
# Enter first number: 17
# Enter second number:4
# 1.0

# %% [markdown]
# Q3. Calculate 3 raised to the power 4.

# %%
num1 = int(input('Enter first number: '))
num2 = int(input('Enter second number:'))
power = num1 ** num2
print(float(power))
# Out:
# Enter first number: 4
# Enter second number:3
# 64.0

# %% [markdown]
# ## Assignment Operators

# %% [markdown]
# Q4. Assign 10 to x and add 5 to it using assignment operator.

# %%
num1 = int(input('Enter first number:'))
x = num1 + 5
print(x)
# Out:
# Enter first number:10
# 15

# %% [markdown]
# Q5. Assign 20 to y and multiply it by 2 using assignment operator.

# %%
num1 = int(input('Enter first number:'))
y = num1 * 2
print(y)
# Out:
# Enter first number:20
# 40

# %% [markdown]
# Q6. Assign 15 to z and subtract 7 using assignment operator.

# %%
num1 = int(input('Enter first number:'))
z = num1 - 7
print(z)
# Out:
# Enter first number:15
# 8

# %% [markdown]
# ## Comparison Operators

# %% [markdown]
# Q7. Check if 10 is greater than 5.

# %%
num1 = int(input('Enter first number:'))
num2 = int(input('Enter second number:'))
if num1 > num2:
    print('True')
else:
    print('False')
# Out:
# Enter first number:10
# Enter second number:5
# True

# %% [markdown]
# Q8. Check if 7 is equal to 9.

# %%
num1= 7
num2 =9
if num1 == num2:
  print(f'{num1} is equal to {num2}')
else:
  print(f'{num1} is not equal to {num2}')
# Out:
# 7 is not equal to 9

# %% [markdown]
# Q9. Check if 8 is not equal to 3.

# %%
num1= int(input('Enter first number:'))
num2 = int(input('Enter second number:'))
if num1 == num2:
  print(f'{num1} is equal to {num2}')
else:
  print(f'{num1} is not equal to {num2}')
# Out:
# Enter first number:8
# Enter second number:3
# 8 is not equal to 3

# %% [markdown]
# ## Logical Operators

# %% [markdown]
# Q10. Check if 5 > 2 and 10 > 3.

# %%
if 5 > 2 and 10 > 3:
  print('True')
else:
  print('False')
# Out:
# True

# %% [markdown]
# Q11. Check if 5 > 10 or 3 < 7.

# %%
if 5 > 10 or 3 < 7:
  print('True')
else:
  print('False')
# Out:
# True

# %% [markdown]
# Q12. Use not operator on condition 10 > 5.

# %%
print(not 10 > 5)
# Out:
# False

# %% [markdown]
# ## Identity Operators

# %% [markdown]
# Q16. Check if a and b refer to the same object.
# Let a = 10, b = 10.

# %%
a = 10
b = 10

print(a is b)
# Out:
# True

# %% [markdown]
# Q18. Compare identity of two variables c and d where c = d = 5.

# %%
c = 5
d = 5
print(c is d)
# Out:
# True

# %% [markdown]
# ## Membership Operators

# %% [markdown]
# Q19. Check if 3 is present in the list [1,2,3,4].

# %%
a = [1,2,3,4]
if 3 in a:
  print('True')
else:
  print('False')
# Out:
# True

# %% [markdown]
# Q20. Check if 'a' is not present in the string 'python'.

# %%
str = 'python'
if 'a' not in str:
  print('True')
else:
  print('False')
# Out:
# True

# %% [markdown]
# Q21. Check if 10 is in the tuple (5, 10, 15).

# %%
a = (5,10,15)
if 10 in a :
  print('True')
else:
  print('False')
#
# Out:
# True
