# %% [markdown]
# # Python Variables Practice (Assignment 1)
#
# **Topics Covered:**
# - Variable creation
# - int, float, str, bool data types
# - Printing variables
# - f-strings

# %% [markdown]
# ## Section 1: Variable Creation & Printing

# %% [markdown]
# ### Question 1
# Create a variable to store your **age** and print it.

# %%
# write your answer

age =35

print(age)

# %% [markdown]
# ### Question 2
# Create a variable to store the **price of a notebook** (can be a decimal value) and print it.

# %%
price_notebook  = input()
print(price_notebook)
# Out:
# 35.50
# 35.50

# %% [markdown]
# ### Question 3
# Create a variable to store your **first name** and print it.

# %%
first_name = 'Azhar'
print(first_name)
# Out:
# Azhar

# %% [markdown]
# ### Question 4
# Create a variable to store whether you have **completed today’s class** (True/False) and print it.

# %%
class_completed_today = True

print(class_completed_today)
# Out:
# True

# %% [markdown]
# ### Question 5
# Create two variables:
# - one to store the **number of classes attended**
# - one to store the **average rating** (float)
# Print both.

# %%
no_of_class_attended = input()
average_rating = input()

print(f'no_of_class_attended', no_of_class_attended)
print(f'average_rating' , average_rating)
# Out:
# 4
# 7.5
# no_of_class_attended 4
# average_rating 7.5

# %% [markdown]
# ## Section 2: Printing using f-strings

# %% [markdown]
# ### Question 6
# Create variables for **name** and **age** and print:
# > My name is Rahul and I am 22 years old.

# %%
Name = 'Rahul'
Age = 22

print(f'My name is {Name} and I am {Age} years old.')
# Out:
# My name is Rahul and I am 22 years old.

# %% [markdown]
# ### Question 7
# Create variables for **item name** and **price** and print:
# > The price of Pen is 10.5 rupees.

# %%
price_pen = 10.5
print(f'The price of Pen is {price_pen} rupees.')
# Out:
# The price of Pen is 10.5 rupees.

# %% [markdown]
# ### Question 8
# Create variables for **batch name** and **class completed status** and print:
# > Batch DA10 class completed status is True.

# %%
batch_name = "DA10"
class_completed = True

print(f"Batch {batch_name} class and completed status is {class_completed}")
# Out:
# Batch DA10 class and completed status is True
